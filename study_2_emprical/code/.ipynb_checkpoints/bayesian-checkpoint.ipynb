# %%
import arviz as az
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import pymc as pm
import xarray as xr
import bambi as bmb
import pickle

# %%
df = pd.read_csv('../data/LL_model_type_iq.csv')

df = pd.read_csv('../data/LL_model_type_iq.csv')
df['model_type'] = df['model_type']*2-1

center_function = lambda x: x - x.mean()
df['iq'] = center_function(df['iq'])
df['LL'] = center_function(df['LL'])
df.drop(columns=['Unnamed: 0'],inplace=True)
df
# Out:
#      subject         iq         LL  model_type
# 0          0  15.685185 -16.014271          -1
# 1          0  15.685185 -10.949829           1
# 2          1  11.685185  15.163491          -1
# 3          1  11.685185  35.957552           1
# 4          2   9.685185  44.950332          -1
# ..       ...        ...        ...         ...
# 103       51  -6.314815 -21.655177           1
# 104       52  -1.314815  33.987517          -1
# 105       52  -1.314815   4.707150           1
# 106       53  -3.314815 -16.069966          -1
# 107       53  -3.314815 -19.873134           1
#
# [108 rows x 4 columns]

# %%
Intercept_prior = bmb.Prior("Normal", mu=0, sigma=10)
IQ_prior = bmb.Prior("Normal", mu=0, sigma=10)
Model_type_prior = bmb.Prior("Normal",  mu=0, sigma=10)
IQ_Model_type_prior = bmb.Prior("Normal",  mu=0, sigma=10)

my_priors = {
        'Intercept':Intercept_prior,
        'iq': IQ_prior,
        'model_type': Model_type_prior,
        'iq:model_type':IQ_Model_type_prior
         }


model = bmb.Model("LL ~ iq*model_type + ( model_type | subject)",
                  df,
                  categorical=['model_type'],
#                   priors=my_priors,
                 ) 
model.build()
model
# model.graph()
model.plot_priors()
# plt.show()
# Out:
# array([[<AxesSubplot:title={'center':'Intercept'}>,
#         <AxesSubplot:title={'center':'iq'}>,
#         <AxesSubplot:title={'center':'model_type\n1'}>],
#        [<AxesSubplot:title={'center':'iq:model_type\n1'}>,
#         <AxesSubplot:title={'center':'1|subject_sigma'}>,
#         <AxesSubplot:title={'center':'model_type|subject_sigma\n1'}>],
#        [<AxesSubplot:title={'center':'LL_sigma'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
results = model.fit(draws=10_000, tune=5000, chains=4, cores=8)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 8 jobs)
# NUTS: [Intercept, iq, model_type, iq:model_type, 1|subject_sigma, 1|subject_offset, model_type|subject_sigma, model_type|subject_offset, LL_sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60000' class='' max='60000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60000/60000 00:29<00:00 Sampling 4 chains, 1,028 divergences]
#     </div>
# ...

# %%
xx = az.summary(results,hdi_prob=.95,round_to=4,stat_focus='median').head(10)
xx
# Out:
#                               median     mad  eti_2.5%  eti_97.5%  \
# Intercept                     2.6780  1.9955   -3.1456     8.6287
# iq                            0.6088  0.1815    0.0757     1.1510
# model_type[1]                -5.4420  1.3852   -9.5257    -1.3931
# iq:model_type[1]              0.0559  0.1294   -0.3260     0.4404
# 1|subject_sigma              18.6614  1.4493   14.8492    23.7048
# model_type|subject_sigma[1]   2.9509  1.7291    0.1395     9.2874
# LL_sigma                     10.2474  0.7662    8.0969    12.8015
# 1|subject[0]                -20.3587  5.4869  -36.5620    -4.1930
# 1|subject[1]                 14.7328  5.3788   -1.4211    30.1309
# 1|subject[2]                 30.4545  5.2462   14.9834    45.9181
#
#                              mcse_median  ess_median    ess_tail   r_hat
# Intercept                         0.0426   7679.8053   5993.0201  1.0008
# iq                                0.0036   9073.1988  11990.3537  1.0002
# ...

# %%
az.plot_trace(results, var_names=("Intercept", "iq", 'model_type','iq:model_type'),
              kind="rank_vlines",figsize=(16, 24))
plt.show()

# %%
import arviz.labels as azl
labeller = azl.MapLabeller(var_name_map={
                            "iq":'',
                            "model_type": '',
                            'iq:model_type': '',
                           })
kwargs = {'bins':100,'color':sns.color_palette('tab10')[9],'histtype':'bar'}
ax = az.plot_posterior(
                  results.posterior,
                  figsize=(16,4),
                  var_names=['iq','model_type','iq:model_type'],
                  grid=(1,3),
                  hdi_prob=.95, # hide
                  lw=3,
                  labeller=labeller,
                  kind='hist',
                  point_estimate=None,#'median'
                 ref_val=0,
                 **kwargs
                 )

ax[0].set_ylabel('Density',size=18)
ax[0].set_xlabel(r'$\beta_{IQ}$',size=18)

ax[0].axvline(x=0,ls=':',color=sns.color_palette('tab10')[4],lw=2)
ax[1].axvline(x=0,ls=':',color=sns.color_palette('tab10')[4],lw=2)
ax[2].axvline(x=0,ls=':',color=sns.color_palette('tab10')[4],lw=2)

ax[0].axvline(x=.61,ls='-',color=sns.color_palette('tab10')[4],lw=2)
ax[1].axvline(x=-4.32,ls='-',color=sns.color_palette('tab10')[4],lw=2)
ax[2].axvline(x=0.0551,ls='-',color=sns.color_palette('tab10')[4],lw=2)

ax[1].set_xlabel(r'$\beta_{Model\/Type}$',size=18)
ax[2].set_xlabel(r'$\beta_{IQ \times Model\/Type}$',size=18)
ax[1].set_title('',size=18)
ax[2].set_title('',size=18)

# plt.savefig('fig_bay_1',dpi=400,bbox_inches='tight')

plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(16, 4))

kwargs = {'bins':100,'color':sns.color_palette('tab10')[9],'histtype':'stepfilled','alpha':.8}
data = [results.posterior.iq,results.posterior.model_type,results.posterior['iq:model_type']]

iq_0 = xx['eti_2.5%'].iq
iq_1 = xx['eti_97.5%'].iq

mt_0 = xx['eti_2.5%']['model_type[1]']
mt_1 = xx['eti_97.5%']['model_type[1]']

iq_mt_0 = xx['eti_2.5%']['iq:model_type[1]']
iq_mt_1 = xx['eti_97.5%']['iq:model_type[1]']

for i,datum in enumerate(data):
    az.plot_dist(datum, kind='hist', hist_kwargs=kwargs,ax=axes[i])
    axes[i].spines.left.set_visible(False)
    axes[i].spines.right.set_visible(False)
    axes[i].spines.top.set_visible(False)
    
    axes[i].set_yticklabels(labels='')
    axes[i].tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,        # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

    axes[i].tick_params(
    axis='x',          
    which='both',
    size=2,
    labelsize=14)
    
    axes[i].axvline(x=0,ls=':',color=sns.color_palette('tab10')[4],lw=3)
    axes[i].axvline(x=datum.median(),ls='-',color=sns.color_palette('tab10')[4],lw=3)
    
axes[0].set_ylabel('Density',size=18)
axes[1].set_ylabel('Density',size=18)
axes[2].set_ylabel('Density',size=18)

axes[0].set_xlabel(r'$\beta_{IQ}$',size=18)
axes[0].plot([iq_0,iq_1],[0.04,0.04],color='k',lw=7)
axes[0].set_xticks(ticks=np.linspace(-0.5,1.5,5),fontsize=20)

axes[1].set_xlabel(r'$\beta_{Model\/Type}$',size=18)
axes[1].plot([mt_0,mt_1],[.005,.005],color='k',lw=7)
axes[1].set_xticks(ticks=np.linspace(-10,0.0,3),fontsize=20)

axes[2].set_xlabel(r'$\beta_{IQ \times Model\/Type}$',size=18)
axes[2].plot([iq_mt_0,iq_mt_1],[.05,.05],color='k',lw=7)
axes[2].set_xticks(ticks=np.linspace(-.5,.5,3),fontsize=20)
axes[2].spines.left.set_visible(True)

# plt.savefig('../plots/fig_5',dpi=400,bbox_inches='tight')

plt.show()

# %%
df = pd.read_csv('../data/oe_iq.csv.csv')
# df['IQ'] = center_function(df['IQ'])
# df['OE'] = center_function(df['OE'])

model_2 = bmb.Model("IQ ~ OE", df) 
model_2.build()


results_2 = model_2.fit(draws=6000, tune=2000, chains=4, cores=8)


# model_2.predict(results_2,kind='pps')
# az.plot_bpv(results_2, kind="p_value")
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 8 jobs)
# NUTS: [Intercept, OE, IQ_sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='32000' class='' max='32000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [32000/32000 00:03<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 2_000 tune and 6_000 draw iterations (8_000 + 24_000 draws total) took 11 seconds.

# %%
az.summary(results_2,hdi_prob=.89,round_to=5,stat_focus='median').head()
# Out:
#               median      mad   eti_5.5%  eti_94.5%  mcse_median   ess_median  \
# Intercept  107.17312  1.69085  103.13376  111.15573      0.01799  28654.52019
# OE           0.01828  0.00492    0.00659    0.03003      0.00005  28700.49563
# IQ_sigma    10.39766  0.69598    8.95956   12.28128      0.00747  25730.48871
#
#               ess_tail    r_hat
# Intercept  18299.16592  1.00041
# OE         17896.95728  1.00019
# IQ_sigma   15594.09878  0.99995

# %%
az.plot_trace(results_2, kind="rank_vlines",figsize=(16, 24))
plt.show()

# %%
xx = df['OE'].values
results_2.posterior["y_model"] = results_2.posterior["Intercept"] + results_2.posterior["OE"] * xr.DataArray(xx)

# %%
import arviz.labels as azl
kwargs = {'bins':100,'color':sns.color_palette('tab10')[9],'histtype':'bar'}
ax = az.plot_posterior(
                  results_2.posterior.OE,
                  figsize=(5,4),
                  hdi_prob=.89, # hide
                  lw=3,
                  labeller=labeller,
                  kind='hist',
                  point_estimate=None,#'median'
                 ref_val=0,
                 **kwargs
                 )

# %%
fig, axes = plt.subplots(1,3,figsize=(16, 5))

# fig a

az.plot_lm(idata=results_2, 
           x=xx, 
           y='IQ',
           num_samples=200,
           y_model="y_model",
           axes=axes[0],
           y_kwargs={ 'marker':"$\circ$", 'markersize':5.5,'color':'k','label':None},
           y_model_mean_kwargs={'color':sns.color_palette('tab10')[4],'lw':3,},
           y_model_plot_kwargs={'color':sns.color_palette('tab10')[9] ,'alpha':.3,'lw':.5},
          )


legend_elements = [
                Line2D([0],[0] ,lw=3,  color=sns.color_palette('tab10')[4], label='Mean'),
                Line2D([0],[0] ,lw=1.5,  color=sns.color_palette('tab10')[9], label='Uncertainty in the mean'),
                Line2D([0],[0] ,lw=0, marker="$\circ$" , markersize=5.5, color='k', label='Subject')

]
axes[0].legend(handles=legend_elements,loc='upper left',fontsize=12) 
axes[0].set_xlim(-4,750)
axes[0].set_ylim(70,150)
axes[0].tick_params(axis='x', which='major', labelsize=14)
axes[0].set_xticks(np.arange(-1,800,150),np.arange(0,801,150),size=14)
axes[0].tick_params(axis='y', which='major', labelsize=14)
axes[0].set_yticks(np.arange(60,161,20),np.arange(60,161,20),size=14)
axes[0].set_xlabel("Epoch",size=18)
axes[0].set_ylabel("IQ",size=18)
axes[0].spines.right.set_visible(False)
axes[0].spines.top.set_visible(False)
axes[0].grid(alpha=.3)

# fig b

kwargs = {'bins':100,'color':sns.color_palette('tab10')[9],'histtype':'stepfilled','alpha':.4}
az.plot_dist(results_2.posterior.OE, kind='hist', hist_kwargs=kwargs,ax=axes[1])

axes[1].set_xticks(ticks=np.linspace(-0.01,0.05,7),fontsize=20)
axes[1].set_yticklabels(labels='')
axes[1].tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,        # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

axes[1].tick_params(
    axis='x',          
    which='both',
    size=2,
    labelsize=14) 

axes[1].plot([0.00655,0.03],[1.5,1.5],color='k',lw=7)
axes[1].axvline(x=0,ls=':',color=sns.color_palette('tab10')[4],lw=3)
axes[1].axvline(x=.018,ls='-',color=sns.color_palette('tab10')[4],lw=3)
axes[1].set_ylabel('Density',size=18)
axes[1].set_xlabel(r'$\beta_{Epoch}$',size=18)
axes[1].spines.right.set_visible(False)
axes[1].spines.top.set_visible(False)
axes[1].spines.left.set_visible(False)


# fig c

with open('../results/iq.pickle', 'rb') as handle:
    iq = pickle.load(handle) 
    
with open('../results/loss_test.pickle', 'rb') as handle:
    loss_test = pickle.load(handle)

ll_test = np.array(ll_test).reshape(54,3,1000)


x = np.array(loss_test).reshape(54,3,1000).mean(axis=1)
a = 110 < np.array(iq)
axes[2].plot(x[a].mean(axis=0)[:500],label='IQ > 110 test',linewidth=2,color=sns.color_palette("tab10", 10)[9])
axes[2].scatter(x=np.argmin(x[a].mean(axis=0)),y=x[a].mean(axis=0).min(),marker='*',color='yellow',s=200,edgecolors='black')
axes[2].plot(x[~a].mean(axis=0)[:500],label='IQ < 110 test',linewidth=2,color=sns.color_palette("tab10", 10)[4])
axes[2].scatter(x=np.argmin(x[~a].mean(axis=0)),y=x[~a].mean(axis=0).min(),marker='*',color='yellow',s=200,edgecolors='black')
axes[2].spines.right.set_visible(False)
axes[2].spines.top.set_visible(False)
axes[2].tick_params(axis='x', which='major', labelsize=14)
axes[2].tick_params(axis='y', which='major', labelsize=14)

axes[2].legend(fontsize=14)
axes[2].set_xlabel('Epoch',size=18)
axes[2].set_ylabel('Loss',size=18)
axes[2].grid(alpha=.3)

plt.savefig('../plots/fig_6',dpi=400,bbox_inches='tight')

plt.show()
# Out:
# /Users/yoavger/miniforge3/envs/pymc_env/lib/python3.10/site-packages/arviz/plots/lmplot.py:209: UserWarning: posterior_predictive not found in idata
#   warnings.warn("posterior_predictive not found in idata", UserWarning)
# /Users/yoavger/miniforge3/envs/pymc_env/lib/python3.10/site-packages/numpy/lib/shape_base.py:1250: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = _nx.array(A, copy=False, subok=True, ndmin=d)
